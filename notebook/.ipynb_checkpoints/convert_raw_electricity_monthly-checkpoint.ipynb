# %%
import pandas as pd
import glob
import os
import warnings
warnings.filterwarnings("ignore")


FILE_PATH = os.path.expanduser("~/git/dataport/metadata/electricity_egauge_hours/")
METADATA_PATH = os.path.expanduser("~/git/dataport/metadata/metadata.csv")
HDF_PATH = os.path.expanduser("~/monthly-12-17.h5")

# %%
# Dropping days when DST changed

dst_times = []
dst_times.append(('2012-03-11 02:00:00', '2012-03-11 03:00:00'))
dst_times.append(('2012-11-04 01:00:00', '2012-11-04 02:00:00'))
dst_times.append(('2013-03-10 02:00:00', '2013-03-10 03:00:00'))
dst_times.append(('2013-11-03 01:00:00', '2013-11-03 02:00:00'))
dst_times.append(('2014-03-09 02:00:00', '2014-03-09 03:00:00'))
dst_times.append(('2014-11-02 01:00:00', '2014-11-02 02:00:00'))
dst_times.append(('2015-03-08 02:00:00', '2015-03-08 03:00:00'))
dst_times.append(('2015-11-01 01:00:00', '2015-11-01 02:00:00'))
dst_times.append(('2016-03-13 02:00:00', '2016-03-13 03:00:00'))
dst_times.append(('2016-11-06 01:00:00', '2016-11-06 02:00:00'))
dst_times.append(('2017-03-12 02:00:00', '2017-03-12 03:00:00'))
dst_times.append(('2017-11-05 01:00:00', '2017-11-05 02:00:00'))

# %%
# Feeds to ignore
feed_ignore = ['gen', 'grid']


#list_of_buildings = glob.glob("/Users/nipunbatra/w/*.csv")
files = os.listdir(FILE_PATH)
file_size= {x:os.path.getsize(FILE_PATH+x) for x in  files if '.csv' in x}
file_series = pd.Series(file_size)
#file_series = file_series.drop(METADATA_PATH)
fs = file_series[file_series>1000]

# %%
store = pd.HDFStore(HDF_PATH, mode='a', complevel=9, complib='blosc')
count = 0

# %%
for building_number_csv in fs.index:
    print ("Done {} of {}".format(count, len(fs)))
    try:
        building_path = os.path.join(FILE_PATH, building_number_csv)
        building_number = int(building_number_csv[:-4])
        if building_number in store.keys():
            continue
        df = pd.read_csv(building_path)
        df.index = pd.to_datetime(df["localhour"])
        df = df.drop("localhour", 1)
        # Dropping feeds
        for feed in feed_ignore:
            if feed in df.columns:
                df = df.drop(feed, 1)

        df = df.mul(1000)

        # Dropping feeds with 0 sum
        cols_to_keep = df.sum()[df.sum()>0].index
        df = df[cols_to_keep]

        # Dropping dataid
        if "dataid" in df.columns:
            df = df.drop('dataid', 1)
        df = df.drop(['Unnamed: 0'], axis=1)


        # Fixing DST issues
        for start, end in dst_times:
            ix_drop = df[start:end].index
            df = df.drop(ix_drop)


        # Assigning local timezone
        df = df.tz_localize('US/Central')

        # Making data float32
        df = df.astype('float32')

        # Write in temp HDF5 store
        store.put(str(building_number), df, format='table')
        count = count + 1
    except Exception as e:
        print(e)
# Out:
# Done 8 of 834
# Done 9 of 834
# Done 10 of 834
# 2017-03-12 02:00:00
# Done 44 of 834
# 2017-03-12 02:00:00
# Done 44 of 834
# Done 45 of 834
# Done 46 of 834
# 2017-03-12 02:00:00
# Done 46 of 834
# Done 47 of 834
# Done 48 of 834
# Done 49 of 834
# Done 50 of 834
# Done 51 of 834
# 2017-03-12 02:00:00
# Done 51 of 834
# 2017-03-12 02:00:00
# Done 51 of 834
# Done 52 of 834
# Done 53 of 834
# 2017-03-12 02:00:00
# Done 53 of 834
# 2017-03-12 02:00:00
# Done 53 of 834
# Done 54 of 834
# 2017-03-12 02:00:00
# Done 54 of 834
# Cannot infer dst time from Timestamp('2017-11-05 01:00:00'), try using the 'ambiguous' argument
# Done 54 of 834
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-bd8fb565cb68> in <module>()
#       4         building_path = os.path.join(FILE_PATH, building_number_csv)
#       5         building_number = int(building_number_csv[:-4])
# ----> 6         if building_number in store.keys():
#       7             continue
#       8         df = pd.read_csv(building_path)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/pytables.py in keys(self)
#     527         have the leading '/'
#     528         """
# --> 529         return [n._v_pathname for n in self.groups()]
#     530
#     531     def __iter__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/pytables.py in groups(self)
#    1075         self._check_if_open()
#    1076         return [
# -> 1077             g for g in self._handle.walk_nodes()
#    1078             if (getattr(g._v_attrs, 'pandas_type', None) or
#    1079                 getattr(g, 'table', None) or
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/pytables.py in <listcomp>(.0)
#    1075         self._check_if_open()
#    1076         return [
# -> 1077             g for g in self._handle.walk_nodes()
#    1078             if (getattr(g._v_attrs, 'pandas_type', None) or
#    1079                 getattr(g, 'table', None) or
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/file.py in walk_nodes(self, where, classname)
#    2123             yield self.get_node(where)
#    2124             for group in self.walk_groups(where):
# -> 2125                 for leaf in self.iter_nodes(group):
#    2126                     yield leaf
#    2127         else:  # only nodes of the named type
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/group.py in _f_iter_nodes(self, classname)
#     744             names = sorted(six.iterkeys(self._v_children))
#     745             for name in names:
# --> 746                 yield self._v_children[name]
#     747         elif classname == 'Group':
#     748             # Returns all the groups alphanumerically sorted
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/misc/proxydict.py in __getitem__(self, key)
#      38
#      39         # Values are not actually stored to avoid extra references.
# ---> 40         return self._get_value_from_container(self._get_container(), key)
#      41
#      42     def __setitem__(self, key, value):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/group.py in _get_value_from_container(self, container, key)
#      40 class _ChildrenDict(ProxyDict):
#      41     def _get_value_from_container(self, container, key):
# ---> 42         return container._f_get_child(key)
#      43
#      44
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/group.py in _f_get_child(self, childname)
#     713
#     714         childpath = join_path(self._v_pathname, childname)
# --> 715         return self._v_file._get_node(childpath)
#     716
#     717
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/file.py in _get_node(self, nodepath)
#    1597             return self.root
#    1598
# -> 1599         node = self._node_manager.get_node(nodepath)
#    1600         assert node is not None, "unable to instantiate node ``%s``" % nodepath
#    1601
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/file.py in get_node(self, key)
#     435
#     436         if self.node_factory:
# --> 437             node = self.node_factory(key)
#     438             self.cache_node(node, key)
#     439
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/group.py in _g_load_child(self, childname)
#    1201             # return ChildClass(self, childname)  # uncomment for debugging
#    1202             try:
# -> 1203                 return ChildClass(self, childname)
#    1204             except Exception as exc:  # XXX
#    1205                 warnings.warn(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/table.py in __init__(self, parentnode, name, description, title, filters, expectedrows, chunkshape, byteorder, _log, track_times)
#     840
#     841         super(Table, self).__init__(parentnode, name, new, filters,
# --> 842                                     byteorder, _log, track_times)
#     843
#     844     def _g_post_init_hook(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/leaf.py in __init__(self, parentnode, name, new, filters, byteorder, _log, track_times)
#     288
#     289
# --> 290         super(Leaf, self).__init__(parentnode, name, _log)
#     291
#     292     def __len__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/node.py in __init__(self, parentnode, name, _log)
#     273
#     274             # This allows extra operations after creating the node.
# --> 275             self._g_post_init_hook()
#     276         except:
#     277             # If anything happens, the node must be closed
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/table.py in _g_post_init_hook(self)
#     876             if igroup:
#     877                 indexname = _index_pathname_of_column(self, colname)
# --> 878                 indexed = indexname in self._v_file
#     879                 self.colindexed[colname] = indexed
#     880                 if indexed:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/file.py in __contains__(self, path)
#    2056
#    2057         try:
# -> 2058             self.get_node(path)
#    2059         except NoSuchNodeError:
#    2060             return False
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/file.py in get_node(self, where, name, classname)
#    1649             basepath = where
#    1650             nodepath = join_path(basepath, name or '') or '/'
# -> 1651             node = self._get_node(nodepath)
#    1652         else:
#    1653             raise TypeError(
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/file.py in _get_node(self, nodepath)
#    1597             return self.root
#    1598
# -> 1599         node = self._node_manager.get_node(nodepath)
#    1600         assert node is not None, "unable to instantiate node ``%s``" % nodepath
#    1601
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/file.py in get_node(self, key)
#     435
#     436         if self.node_factory:
# --> 437             node = self.node_factory(key)
#     438             self.cache_node(node, key)
#     439
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/group.py in _g_load_child(self, childname)
#    1194                 # Default is a Group class
#    1195                 ChildClass = Group
# -> 1196             return ChildClass(self, childname, new=False)
#    1197         elif node_type == "Leaf":
#    1198             ChildClass = self._g_get_child_leaf_class(childname, warn=True)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/index.py in __init__(self, parentnode, name, atom, title, kind, optlevel, filters, tmp_dir, expectedrows, byteorder, blocksizes, new)
#     398         """The `open_file()` function, to avoid a circular import."""
#     399
# --> 400         super(Index, self).__init__(parentnode, name, title, new, filters)
#     401
#     402     def _g_post_init_hook(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/group.py in __init__(self, parentnode, name, title, new, filters, _log)
#     237
#     238         # Finally, set up this object as a node.
# --> 239         super(Group, self).__init__(parentnode, name, _log)
#     240
#     241     def _g_post_init_hook(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tables/node.py in __init__(self, parentnode, name, _log)
#     266                 self._v_objectid = self._g_create()
#     267             else:
# --> 268                 self._v_objectid = self._g_open()
#     269
#     270             # The node *has* been created, log that.
#
# KeyboardInterrupt:
